# %% [markdown]
# <a href="https://colab.research.google.com/github/Fiandika/pemrograman-komputer-5018251124/blob/main/W02_Engineering_Calculator_5018251124(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 2 Assignment
# ## Engineering Unit and Electrical Calculator
#
# Nama : Fiandika Satria Wirasena
#
# NRP : 5018251124
#
# Kelas : Pemrograman Komputer

# %%
print("Task 1: Speed Unit Conversion")

speed_kmh = float(input("Enter speed [km/h]: "))
speed_ms = speed_kmh / 3.6

print(f"Speed [m/s] = {speed_ms:.2f} m/s")
# Out:
# Task 1: Speed Unit Conversion
# Enter speed [km/h]:  100
# Speed [m/s] = 27.78 m/s

# %%
print("Task 2: Power Unit Conversion")

Power_kW = float(input("Power[kW]: "))
Power_W = Power_kW * 1000

print(f"Power = {Power_W:.2f} W")
# Out:
# Task 2: Power Unit Conversion
# Power[kW]:  12.5
# Power = 12500.00 W

# %%
print("Task 3: Electrical Power and Energy Calculator")
voltage_V = float(input("Voltage [V]: "))

current_A = float(input("Current [A]: "))

time_hour = float(input("Operating Time [Hour]: "))

power_W = voltage_V * current_A

energy_Wh = power_W * time_hour

print(" ")
print("===== ELECTRICAL CALCULATION =====")
print(f"Voltage : {voltage_V:.2f} V")
print(f"Current : {current_A:.2f} A")
print(f"Power : {power_W:.2f} W")
print(f"Operating Time : {time_hour:.2f} hour")
print(f"Energy : {energy_Wh:.2f} Wh")
# Out:
# Task 3: Electrical Power and Energy Calculator
# Voltage [V]:  24
# Current [A]:  8.5
# Operating Time [Hour]:  3.0
#
# ===== ELECTRICAL CALCULATION =====
# Voltage : 24.00 V
# Current : 8.50 A
# Power : 204.00 W
# Operating Time : 3.00 hour
# Energy : 612.00 Wh

# %%
print("Task 4: Comparison and Logical Operators")
voltage_V = float(input("Voltage [V]: "))

current_A = float(input("Current [A]: "))

time_hour = float(input("Operating Time [Hour]: "))

power_W = voltage_V * current_A

energy_Wh = power_W * time_hour

power_W_limit = 200
voltage_V_limit =24

is_high_power = power_W > power_W_limit
is_high_voltage = voltage_V > voltage_V_limit

print(" ")
print("===== ELECTRICAL CALCULATION TEST =====")
print(f"Voltage : {voltage_V:.2f} V")
print(f"Current : {current_A:.2f} A")
print(f"Power : {power_W:.2f} W")
print(f"Operating Time : {time_hour:.2f} hour")
print(f"Energy : {energy_Wh:.2f} Wh")
print(f"High power : {is_high_power}")
print(f"High voltage : {is_high_voltage}")
print(f"Both conditions : {is_high_power and is_high_voltage}")
print(f"Any condition : {is_high_power or is_high_voltage}")
# Out:
# Task 4: Comparison and Logical Operators
# Voltage [V]:  24
# Current [A]:  8.5
# Operating Time [Hour]:  3.0
#
# ===== ELECTRICAL CALCULATION TEST =====
# Voltage : 24.00 V
# Current : 8.50 A
# Power : 204.00 W
# Operating Time : 3.00 hour
# Energy : 612.00 Wh
# High power : True
# High voltage : False
# Both conditions : False
# Any condition : True

# %%
print("Test Case 1")
voltage_V = float(input("Voltage [V]: "))

current_A = float(input("Current [A]: "))

time_hour = float(input("Operating Time [Hour]: "))

power_W = voltage_V * current_A

energy_Wh = power_W * time_hour

power_W_limit = 200
voltage_V_limit =24

is_high_power = power_W > power_W_limit
is_high_voltage = voltage_V > voltage_V_limit

print(" ")
print("===== ELECTRICAL CALCULATION TEST 1 =====")
print(f"Voltage : {voltage_V:.2f} V")
print(f"Current : {current_A:.2f} A")
print(f"Power : {power_W:.2f} W")
print(f"Operating Time : {time_hour:.2f} hour")
print(f"Energy : {energy_Wh:.2f} Wh")
print(f"High power : {is_high_power}")
print(f"High voltage : {is_high_voltage}")
print(f"Both conditions : {is_high_power and is_high_voltage}")
print(f"Any condition : {is_high_power or is_high_voltage}")
# Out:
# Test Case 1
# Voltage [V]:  12
# Current [A]:  5.0
# Operating Time [Hour]:  2.0
#
# ===== ELECTRICAL CALCULATION TEST 1 =====
# Voltage : 12.00 V
# Current : 5.00 A
# Power : 60.00 W
# Operating Time : 2.00 hour
# Energy : 120.00 Wh
# High power : False
# High voltage : False
# Both conditions : False
# Any condition : False

# %%
print("Test Case 2")
voltage_V = float(input("Voltage [V]: "))

current_A = float(input("Current [A]: "))

time_hour = float(input("Operating Time [Hour]: "))

power_W = voltage_V * current_A

energy_Wh = power_W * time_hour

power_W_limit = 200
voltage_V_limit =24

is_high_power = power_W > power_W_limit
is_high_voltage = voltage_V > voltage_V_limit

print(" ")
print("===== ELECTRICAL CALCULATION TEST 2 =====")
print(f"Voltage : {voltage_V:.2f} V")
print(f"Current : {current_A:.2f} A")
print(f"Power : {power_W:.2f} W")
print(f"Operating Time : {time_hour:.2f} hour")
print(f"Energy : {energy_Wh:.2f} Wh")
print(f"High power : {is_high_power}")
print(f"High voltage : {is_high_voltage}")
print(f"Both conditions : {is_high_power and is_high_voltage}")
print(f"Any condition : {is_high_power or is_high_voltage}")
# Out:
# Test Case 2
# Voltage [V]:  24
# Current [A]:  8.5
# Operating Time [Hour]:  3.0
#
# ===== ELECTRICAL CALCULATION TEST 2 =====
# Voltage : 24.00 V
# Current : 8.50 A
# Power : 204.00 W
# Operating Time : 3.00 hour
# Energy : 612.00 Wh
# High power : True
# High voltage : False
# Both conditions : False
# Any condition : True

# %%
print("Test Case 3")
voltage_V = float(input("Voltage [V]: "))

current_A = float(input("Current [A]: "))

time_hour = float(input("Operating Time [Hour]: "))

power_W = voltage_V * current_A

energy_Wh = power_W * time_hour

power_W_limit = 200
voltage_V_limit =24

is_high_power = power_W > power_W_limit
is_high_voltage = voltage_V > voltage_V_limit

print(" ")
print("===== ELECTRICAL CALCULATION TEST 3 =====")
print(f"Voltage : {voltage_V:.2f} V")
print(f"Current : {current_A:.2f} A")
print(f"Power : {power_W:.2f} W")
print(f"Operating Time : {time_hour:.2f} hour")
print(f"Energy : {energy_Wh:.2f} Wh")
print(f"High power : {is_high_power}")
print(f"High voltage : {is_high_voltage}")
print(f"Both conditions : {is_high_power and is_high_voltage}")
print(f"Any condition : {is_high_power or is_high_voltage}")
# Out:
# Test Case 3
# Voltage [V]:  48
# Current [A]:  10.0
# Operating Time [Hour]:  1.5
#
# ===== ELECTRICAL CALCULATION TEST 3 =====
# Voltage : 48.00 V
# Current : 10.00 A
# Power : 480.00 W
# Operating Time : 1.50 hour
# Energy : 720.00 Wh
# High power : True
# High voltage : True
# Both conditions : True
# Any condition : True

# %% [markdown]
# # Short Reflection
#
# 1. Apa perbedaan int dan float?
#
# int merupakan tipe data berupa bilangan bulat, sedangkan float merupakan tipe data berupa bilangan bulat atau pecahan.
#
# 2. Mengapa hasil input() perlu dikonversi menggunakan float() untuk perhitungan numerik?
#
# Hasil dari input() perlu dikonversi menjadi float() karena input() secara otomatis membaca perintah yang dimasukkan sebagai tipe data str atau string.
#
# 3. Apa perbedaan operator = dan == dalam Python?
#
# Perbedaan operator = dan == adalah operator = merupakan suatu operator untuk mendefinisikan suatu nilai ke dalam sebuah variabel, sedangkan operator == merupakan suatu operator untuk membandingkan 2 buah nilai
#
# 4. Apa fungsi operator and dan or?
#
# Perbedaan antara kedua operator tersebut adalah operator and hanya akan menghasilkan true jika semua kondisi yang dihubungkan bernilai benar, sedangkan operator or akan menghasilkan true jika salah satu kondisi benar
#
# 5.  Apa satu kesalahan yang Anda temui saat mengerjakan tugas ini, dan bagaimana Anda memperbaikinya?
#
# Kesalahan yang saya temui adalah kesalahan dalam pendefinisian beberapa nilai yang dibutuhkan dan cara memperbaikinya adalah dengan cara mendefinisikan semua nilai secara hati-hati.
